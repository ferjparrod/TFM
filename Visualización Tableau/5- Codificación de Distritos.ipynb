# %% [markdown]
# <h1>Codificación de Distritos</h1>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline

cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None) # para mostrar todas las filas
pd.set_option('display.max_columns', None) # para mostrar todas las columnas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Proyecto Final Bootcamp/Notebooks y datasets definitivos/data"
# Out:
# Accidentalidad_final.csv     Coordenadas_ocio.csv
# Accidentalidad_final.gsheet  dfsemifinal_Accidentalidad.csv
# Accidentefinal.csv	     noche_ocio.xml
# Accidentes.csv		     Radares_Madrid.csv
# CALENDARIO.csv

# %%
#Cargo Datos
full_df = pd.read_csv('/content/drive/My Drive/Proyecto Final Bootcamp/Notebooks y datasets definitivos/data/Accidentefinal.csv', sep=';', decimal=',')
full_df.head(5)
# Out:
#    Unnamed: 0 Lesividad     Rango_horario Dia_semana  \
# 0           0        HL    DE 9:00 A 9:59     JUEVES
# 1           1        HG  DE 21:00 A 21:59     JUEVES
# 2           2        HL  DE 23:00 A 23:59     JUEVES
# 3           3        IL    DE 8:00 A 8:59     JUEVES
# 4           4        IL  DE 19:00 A 19:59     JUEVES
#
#                          Distrito  \
# 0  CHAMARTIN
# 1  CHAMARTIN
# 2  CENTRO
# 3  LATINA
# 4  CHAMBERI
#
#                                      Lugar_accidente       Parte Granizo  \
# 0                         AUTOVIA M-30 CALZADA 2 KM.  2014/10641      NO
# 1  CALLE DEL PRINCIPE DE VERGARA - PLAZA DE CATALUÑA  2014/10636      NO
# 2                                   PLAZA DE CIBELES  2014/10646      NO
# 3                                CALLE VIA CARPETANA  2014/10766      NO
# 4                     CALLE DE FERNANDEZ DE LOS RIOS  2014/10635      NO
#
#   Hielo Hielo.1 Lluvia Niebla Seco Nieve Mojada Aceite Barro Gravilla Hielo.2  \
# ...

# %%
full_df.columns
# Out:
# Index(['Unnamed: 0', 'Lesividad', 'Rango_horario', 'Dia_semana', 'Distrito',
#        'Lugar_accidente', 'Parte', 'Granizo', 'Hielo', 'Hielo.1', 'Lluvia',
#        'Niebla', 'Seco', 'Nieve', 'Mojada', 'Aceite', 'Barro', 'Gravilla',
#        'Hielo.2', 'Hielo.3', 'Seca_limpia', 'Tipo_accidente', 'Tipo_vehiculo',
#        'Tipo_persona', 'Sexo', 'Tramo_edad', 'Latitud', 'Longitud',
#        'Distancia_ocio_km', 'Lejania_ocio', 'Distancia_radares_km',
#        'Lejania_radares', 'Fecha_formato', 'Year', 'Mes', 'Dia', 'Dia_habil'],
#       dtype='object')

# %%
full_df['Distrito'].unique()
# Out:
# array(['CHAMARTIN                     ', 'CENTRO                        ',
#        'LATINA                        ', 'CHAMBERI                      ',
#        'TETUAN                        ', 'SALAMANCA                     ',
#        'PUENTE DE VALLECAS            ', 'SAN BLAS                      ',
#        'MONCLOA-ARAVACA               ', 'CIUDAD LINEAL                 ',
#        'VILLA DE VALLECAS             ', 'HORTALEZA                     ',
#        'ARGANZUELA                    ', 'RETIRO                        ',
#        'FUENCARRAL-EL PARDO           ', 'CARABANCHEL                   ',
#        'VILLAVERDE                    ', 'VICALVARO                     ',
#        'MORATALAZ                     ', 'USERA                         ',
#        'BARAJAS                       ', 'VILLA DE VALLECAS'],
#       dtype=object)

# %%
DF_1 = full_df[full_df['Distrito']=='SAN BLAS                      ']
DF_2 = full_df[full_df['Distrito']=='CENTRO                        ']
DF_3 = full_df[full_df['Distrito']=='FUENCARRAL-EL PARDO           ']
DF_4 = full_df[full_df['Distrito']=='MONCLOA-ARAVACA               ']
DF_5 = full_df[full_df['Distrito']=='SALAMANCA                     ']
DF_6 = full_df[full_df['Distrito']=='RETIRO                        ']
DF_7 = full_df[full_df['Distrito']=='MORATALAZ                     ']
DF_8 = full_df[full_df['Distrito']=='CIUDAD LINEAL                 ']
DF_9 = full_df[full_df['Distrito']=='LATINA                        ']
DF_10 = full_df[full_df['Distrito']=='BARAJAS                       ']
DF_11 = full_df[full_df['Distrito']=='VICALVARO                     ']
DF_12 = full_df[full_df['Distrito']=='CHAMARTIN                     ']
DF_13 = full_df[full_df['Distrito']=='CARABANCHEL                   ']
DF_14 = full_df[full_df['Distrito']=='PUENTE DE VALLECAS            ']
DF_15 = full_df[full_df['Distrito']=='VILLA DE VALLECAS             ']
DF_16 = full_df[full_df['Distrito']=='TETUAN                        ']
DF_17 = full_df[full_df['Distrito']=='HORTALEZA                     ']
DF_18 = full_df[full_df['Distrito']=='ARGANZUELA                    ']
DF_19 = full_df[full_df['Distrito']=='CHAMBERI                      ']
DF_20 = full_df[full_df['Distrito']=='USERA                         ']
DF_21 = full_df[full_df['Distrito']=='VILLAVERDE                    ']
DF_22 = full_df[full_df['Distrito']=='VILLA DE VALLECAS']

# %%
DF_1["CodDistrit"] = "20"
DF_2["CodDistrit"] = "01"
DF_3["CodDistrit"] = "08"
DF_4["CodDistrit"] = "09"
DF_5["CodDistrit"] = "04"
DF_6["CodDistrit"] = "03"
DF_7["CodDistrit"] = "14"
DF_8["CodDistrit"] = "15"
DF_9["CodDistrit"] = "10"
DF_10["CodDistrit"] = "21"
DF_11["CodDistrit"] = "19"
DF_12["CodDistrit"] = "05"
DF_13["CodDistrit"] = "11"
DF_14["CodDistrit"] = "13"
DF_15["CodDistrit"] = "18"
DF_16["CodDistrit"] = "06"
DF_17["CodDistrit"] = "16"
DF_18["CodDistrit"] = "02"
DF_19["CodDistrit"] = "07"
DF_20["CodDistrit"] = "12"
DF_21["CodDistrit"] = "17"
DF_22["CodDistrit"] = "18"

# %%
# DF_1.head(5)
df_final = pd.concat([DF_1, DF_2,DF_3,DF_4, DF_5,DF_6,DF_7,DF_8,DF_9,DF_10,DF_11,DF_12,DF_13,DF_14,DF_15,DF_16,DF_17,DF_18,DF_19,DF_20,DF_21,DF_22])

# %%
df_final.head(5)
# Out:
#     Unnamed: 0 Lesividad     Rango_horario Dia_semana  \
# 9            9        IL    DE 7:00 A 7:59     JUEVES
# 10          10        IL  DE 14:00 A 14:59     JUEVES
# 11          11        HL    DE 7:00 A 7:59     JUEVES
# 30          30        HL  DE 14:00 A 14:59     JUEVES
# 70          70        HL  DE 14:00 A 14:59     MARTES
#
#                           Distrito  \
# 9   SAN BLAS
# 10  SAN BLAS
# 11  SAN BLAS
# 30  SAN BLAS
# 70  SAN BLAS
#
#                                      Lugar_accidente       Parte Granizo  \
# 9   AUTOVIA M-40 - AVENIDA DE CANILLEJAS A VICALVARO  2014/10608      NO
# 10                 AVENIDA SEPTIMA - CALLE DE ALCALA  2014/10687      NO
# 11  AUTOVIA M-40 - AVENIDA DE CANILLEJAS A VICALVARO  2014/10608      NO
# 30                 AVENIDA SEPTIMA - CALLE DE ALCALA  2014/10687      NO
# 70                                  CALLE DEL NECTAR   2014/2139      NO
#
#    Hielo Hielo.1 Lluvia Niebla Seco Nieve Mojada Aceite Barro Gravilla  \
# ...

# %%
#genero datos
df_final.to_csv('/content/drive/My Drive/Proyecto Final Bootcamp/Notebooks y datasets definitivos/data/AccidentalidadFinal_TABLEAU.csv', sep=';', decimal=',', index=False)

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0', 'Lesividad', 'Rango_horario', 'Dia_semana', 'Distrito',
#        'Lugar_accidente', 'Parte', 'Granizo', 'Hielo', 'Hielo.1', 'Lluvia',
#        'Niebla', 'Seco', 'Nieve', 'Mojada', 'Aceite', 'Barro', 'Gravilla',
#        'Hielo.2', 'Hielo.3', 'Seca_limpia', 'Tipo_accidente', 'Tipo_vehiculo',
#        'Tipo_persona', 'Sexo', 'Tramo_edad', 'Latitud', 'Longitud',
#        'Distancia_ocio_km', 'Lejania_ocio', 'Distancia_radares_km',
#        'Lejania_radares', 'Fecha_formato', 'Year', 'Mes', 'Dia', 'Dia_habil',
#        'CodDistrit'],
#       dtype='object')
